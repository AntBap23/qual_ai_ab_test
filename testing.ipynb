# %%
import pandas as pd

# %%
df = pd.read_csv("navigation_ab_test.csv")

# %%
df.head()
# Out:
#      event_id             timestamp    user_id session_id     study_id  \
# 0  evt_000001  2026-04-18T09:00:00Z  user_0001  sess_0001  study_orbit
# 1  evt_000002  2026-04-18T09:00:04Z  user_0001  sess_0001  study_orbit
# 2  evt_000003  2026-04-18T09:00:20Z  user_0001  sess_0001  study_orbit
# 3  evt_000004  2026-04-18T09:00:26Z  user_0001  sess_0001  study_orbit
# 4  evt_000005  2026-04-18T09:00:28Z  user_0001  sess_0001  study_orbit
#
#     variant            event_name       page target_page workflow_stage  \
# 0  vertical  nav_variant_assigned    sign-in         NaN          entry
# 1  vertical             page_view  dashboard         NaN          entry
# 2  vertical        study_selected  dashboard         NaN          entry
# 3  vertical             nav_click  dashboard   workspace      workspace
# 4  vertical             page_view  workspace         NaN      workspace
#
#              task_name  success  time_since_session_start_seconds  \
# ...
